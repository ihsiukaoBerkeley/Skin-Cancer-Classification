# %% [markdown]
# # Step 1: Importing Essential Libraries

# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# # Step 2: Loading data and Making labels

# %%
#Dataset used: https://www.kaggle.com/kmader/skin-cancer-mnist-ham10000
path='archive/hmnist_28_28_RGB.csv'
meta_path = "archive/HAM10000_metadata.csv"

# %%
df = pd.read_csv(path)
metadata = pd.read_csv(meta_path)

# %%
#drop NA values
meta_set = metadata[["age", "sex", "localization"]]
df = pd.concat([meta_set, df], axis=1)
df = df.dropna()
df = df.iloc[:,3:]
df.tail()
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 10010        183        165        181        182        165        180
# 10011          2          3          1         38         33         32
# 10012        132        118        118        167        149        149
# 10013        160        124        146        164        131        152
# 10014        175        142        121        181        150        134
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 10010        184        166        182        188  ...        208        185
# 10011        121        104        103        132  ...         96         79
# 10012        175        156        160        184  ...        204        181
# 10013        167        127        146        169  ...        185        162
# 10014        181        150        133        178  ...        159         79
#
#        pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 10010        187        208        186        186        206        187
# 10011         76         24         23         21          3          4
# 10012        178        181        159        153        172        151
# 10013        167        184        157        166        185        162
# 10014         82        174        137        125        175        139
#
#        pixel2351  label
# 10010        189      0
# 10011          1      0
# 10012        145      0
# 10013        172      0
# 10014        126      6
#
# [5 rows x 2353 columns]

# %% [markdown]
# # Step 3: Train Test Split

# %%
# Split into train, validation, and test.
np.random.seed(2070404)

# Shuffle all records.
df_shuffle = df.sample(frac = 1)

# Create split counts.
splits = np.multiply(len(df_shuffle), (0.6,0.2,0.2)).astype(int)
print(f"Split counts (train/ validation/ test): {splits}")

# Create split data sets.
train_set, valid_set, test_set = np.split(df_shuffle, [splits[0], splits[0] + splits[1]])

# Reset split set indicies.
train_set.reset_index(drop = True, inplace = True)
valid_set.reset_index(drop = True, inplace = True)
test_set.reset_index(drop = True, inplace = True)
# Out:
# Split counts (train/ validation/ test): [5974 1991 1991]

# %%
print(len(train_set))
# Out:
# 5974

# %%
print(len(test_set))
# Out:
# 1993

# %%
df.label.unique()
# Out:
# array([2, 4, 3, 6, 5, 1, 0])

# %%
#separate features and labels
y_train = train_set['label']
x_train = train_set.drop(columns=['label'])
y_valid = valid_set['label']
x_valid = valid_set.drop(columns=['label'])
y_test = test_set['label']
x_test = test_set.drop(columns=['label'])

columns = list(x_train)

# %% [markdown]
# # Step 4: Exploratory Data Analysis and Preprocessing

# %%
import matplotlib.pyplot as plt
import random

#reshape images from 1D to RGB
num=random.randint(0,6000)
x_train = np.array(x_train, dtype=np.uint8).reshape(-1,28,28,3)
x_valid = np.array(x_valid, dtype=np.uint8).reshape(-1,28,28,3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D, Dropout, BatchNormalization
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow import keras
import tensorflow as tf
# Out:
# 2023-12-05 22:20:08.567443: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Step 5: Model Building (CNN)

# %%
def build_model(kernel_size = 2, pool_size = 2, learning_rate = 0.001, optimizer_name = "Adam", additional_dense = True):
    """
    Build a CNN model using Keras.

    Args:
    kernel_size: convolution layer kernel size
    pool_size: pooling layer pool size
    learning_rate: optimizer learning rate
    optimizer_name: optimizer used to compile the model
    additional_dense: whether to add an additional dense layer

    Returns:
    model: A tf.keras model
    """
    
    #clear session
    tf.keras.backend.clear_session()
    model = tf.keras.Sequential()

    #add input layer
    model.add(keras.layers.Input(shape=[28, 28, 3]))

    #add convolution layer 1
    model.add(tf.keras.layers.Conv2D(
        filters = 32, kernel_size = (kernel_size, kernel_size),
        strides=(1,1), padding='same',
        data_format = 'channels_last',
        input_shape = (28, 28, 3),  # Updated input shape for RGB
        name='conv_1', activation='relu'))

    #add pooling layer 1
    model.add(tf.keras.layers.MaxPool2D(
        pool_size= (pool_size, pool_size), name = 'pool_1'))

    #add convolution layer 2
    model.add(tf.keras.layers.Conv2D(
        filters = 64, kernel_size = (kernel_size, kernel_size),
        strides = (1,1), padding = 'same',
        name = 'conv_2', activation = 'relu'))

    #add pooling layer 2
    model.add(tf.keras.layers.MaxPool2D(
        pool_size = (pool_size, pool_size), name = 'pool_2'))

    #add flattening layer
    model.add(tf.keras.layers.Flatten())


    #add dense layer 1
    model.add(tf.keras.layers.Dense(
        units = 1024, name = 'fc_1', 
        activation = 'relu'))

    #dropout
    model.add(tf.keras.layers.Dropout(rate = 0.5))
    
    if additional_dense:
        #add dense layer 2
        model.add(tf.keras.layers.Dense(
            units = 1024, name = 'fc_2', 
            activation = 'relu'))

    #add output layer
    model.add(tf.keras.layers.Dense(
        units = 7, name = 'fc_3',
        activation = 'softmax'))

    if optimizer_name == "Adam":
        optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate)
    elif optimizer_name == "SGD":
        optimizer = tf.keras.optimizers.SGD(learning_rate = learning_rate)
    elif optimizer_name == "Adagrad":
        optimizer = tf.keras.optimizers.Adagrad(learning_rate = learning_rate)

    #compile model
    model.compile(loss = 'sparse_categorical_crossentropy',
                  optimizer = optimizer,
                  metrics = ['accuracy'])
                
    return model

# %% [markdown]
# # Step 6: Fitting the Model with Different Hyper-parameters

# %% [markdown]
# ### 6.1: fit models with and without an additional dense layer with different kernel sizes

# %%
from datetime import datetime

#list of kernel sizes to fit
kernel_list = [1, 2, 3, 4, 5]

kernel_dict = {}

for i in kernel_list:
    
    #fit model with an additional dense layer
    start_time = datetime.now()
    print("-----kernel size: " + str(i) + "-----")
    model = build_model(kernel_size = i, pool_size = 2, learning_rate = 0.001, optimizer_name = "Adam", additional_dense = True)
    history_true = model.fit(x_train,
                        y_train,
                        validation_data=(x_valid, y_valid),
                        batch_size = 64,
                        epochs = 10)

    end_time = datetime.now()
    print('Duration: {}'.format(end_time - start_time))
    
    #fit model without an additional dense layer
    start_time = datetime.now()
    print("-----kernel size: " + str(i) + "-----")
    model = build_model(kernel_size = i, pool_size = 2, learning_rate = 0.001, optimizer_name = "Adam", additional_dense = False)
    history_false = model.fit(x_train,
                        y_train,
                        validation_data=(x_valid, y_valid),
                        batch_size = 64,
                        epochs = 10)

    end_time = datetime.now()
    print('Duration: {}'.format(end_time - start_time))
    
    #store training results
    kernel_dict[i] = [history_true.history['accuracy'][-1], history_true.history['val_accuracy'][-1], history_false.history['accuracy'][-1], history_false.history['val_accuracy'][-1]]
# Out:
# -----kernel size: 1-----
# Epoch 1/10
# 94/94 [==============================] - 4s 37ms/step - loss: 14.9724 - accuracy: 0.5820 - val_loss: 1.0136 - val_accuracy: 0.6735
# Epoch 2/10
# 94/94 [==============================] - 3s 36ms/step - loss: 1.0515 - accuracy: 0.6682 - val_loss: 1.0082 - val_accuracy: 0.6735
# Epoch 3/10
# 94/94 [==============================] - 3s 36ms/step - loss: 1.0456 - accuracy: 0.6661 - val_loss: 0.9928 - val_accuracy: 0.6735
# Epoch 4/10
# 94/94 [==============================] - 3s 36ms/step - loss: 1.0349 - accuracy: 0.6682 - val_loss: 0.9908 - val_accuracy: 0.6735
# Epoch 5/10
# 94/94 [==============================] - 3s 36ms/step - loss: 1.0179 - accuracy: 0.6687 - val_loss: 0.9801 - val_accuracy: 0.6735
# Epoch 6/10
# 94/94 [==============================] - 3s 36ms/step - loss: 1.0268 - accuracy: 0.6687 - val_loss: 0.9624 - val_accuracy: 0.6735
# Epoch 7/10
# 94/94 [==============================] - 3s 36ms/step - loss: 1.0143 - accuracy: 0.6676 - val_loss: 0.9717 - val_accuracy: 0.6735
# Epoch 8/10
# 94/94 [==============================] - 3s 36ms/step - loss: 1.0108 - accuracy: 0.6684 - val_loss: 1.0098 - val_accuracy: 0.6735
# Epoch 9/10
# 94/94 [==============================] - 3s 36ms/step - loss: 1.0281 - accuracy: 0.6661 - val_loss: 0.9883 - val_accuracy: 0.6735
# Epoch 10/10
# 94/94 [==============================] -
10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.8007 - accuracy: 0.7129 - val_loss: 0.8379 - val_accuracy: 0.7082
# Epoch 8/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7730 - accuracy: 0.7205 - val_loss: 0.8158 - val_accuracy: 0.7223
# Epoch 9/10
# 94/94 [==============================] - 3s 32ms/step - loss: 0.7622 - accuracy: 0.7272 - val_loss: 0.8101 - val_accuracy: 0.7152
# Epoch 10/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7541 - accuracy: 0.7278 - val_loss: 0.8173 - val_accuracy: 0.7107
# Duration: 0:00:29.763339
# -----kernel size: 3-----
# Epoch 1/10
# 94/94 [==============================] - 5s 48ms/step - loss: 10.6978 - accuracy: 0.6205 - val_loss: 0.9391 - val_accuracy: 0.6786
# Epoch 2/10
# 94/94 [==============================] - 4s 48ms/step - loss: 0.9567 - accuracy: 0.6672 - val_loss: 0.9290 - val_accuracy: 0.6554
# Epoch 3/10
# 94/94 [==============================] - 5s 48ms/step - loss: 0.9023 - accuracy: 0.6744 - val_loss: 0.8851 - val_accuracy: 0.6786
# Epoch 4/10
# 94/94 [==============================] - 4s 47ms/step - loss: 0.8576 - accuracy: 0.6823 - val_loss: 0.8680 - val_accuracy: 0.6991
# Epoch 5/10
# 94/94 [==============================] - 4s 48ms/step - loss: 0.8346 - accuracy: 0.6997 - val_loss: 0.8550 - val_accuracy: 0.6886
# Epoch 6/10
# 94/94 [==============================] - 5s 48ms/step - loss: 0.8287 - accuracy: 0.6960 - val_loss: 0.8966 - val_accuracy: 0.6966
# Epoch 7/10
# 94/94 [==============================] - 4s 48ms/step - loss: 0.8285 - accuracy: 0.7025 - val_loss: 0.8535 - val_accuracy: 0.6941
# Epoch 8/10
# 94/94 [==============================] - 4s 47ms/step - loss: 0.8227 - accuracy: 0.7029 - val_loss: 0.8799 - val_accuracy: 0.6946
# Epoch 9/10
# 94/94 [==============================] - 4s 47ms/step - loss: 0.8118 - accuracy: 0.7057 - val_loss: 0.8208 - val_accuracy: 0.7042
# Epoch 10/10
# 94/94 [==============================] - 5s 48ms/step - loss: 0.7791 - accuracy: 0.7171 - val_loss: 0.8199 - val_accuracy: 0.7082
# Duration: 0:00:45.357611
# -----kernel size: 3-----
# Epoch 1/10
# 94/94 [==============================] - 4s 39ms/step - loss: 10.1115 - accuracy: 0.6272 - val_loss: 0.9689 - val_accuracy: 0.6765
# Epoch 2/10
# 94/94 [==============================] - 4s 38ms/step - loss: 0.9287 - accuracy: 0.6776 - val_loss: 0.8922 - val_accuracy: 0.6791
# Epoch 3/10
# 94/94 [==============================] - 4s 38ms/step - loss: 0.8739 - accuracy: 0.6856 - val_loss: 0.8831 - val_accuracy: 0.6891
# Epoch 4/10
# 94/94 [==============================] - 4s 39ms/step - loss: 0.8379 - accuracy: 0.7052 - val_loss: 0.8280 - val_accuracy: 0.7087
# Epoch 5/10
# 94/94 [==============================] - 4s 38ms/step - loss: 0.8141 - accuracy: 0.7151 - val_loss: 0.8898 - val_accuracy: 0.6961
# Epoch 6/10
# 94/94 [==============================] - 4s 38ms/step - loss: 0.7701 - accuracy: 0.7285 - val_loss: 0.8471 - val_accuracy: 0.7017
# Epoch 7/10
# 94/94 [==============================] - 4s 39ms/step - loss: 0.7304 - accuracy: 0.7402 - val_loss: 0.8698 - val_accuracy: 0.7042
# Epoch 8/10
# 94/94 [==============================] - 4s 39ms/step - loss: 0.7169 - accuracy: 0.7437 - val_loss: 0.8640 - val_accuracy: 0.7072
# Epoch 9/10
# 94/94 [==============================] - 4s 39ms/step - loss: 0.6914 - accuracy: 0.7476 - val_loss: 0.8607 - val_accuracy: 0.7047
# Epoch 10/10
# 94/94 [==============================] - 4s 38ms/step - loss: 0
# Epoch 2/10
# 94/94 [==============================] - 7s 70ms/step - loss: 1.0470 - accuracy: 0.6656 - val_loss: 1.0591 - val_accuracy: 0.6730
# Epoch 3/10
# 94/94 [==============================] - 7s 71ms/step - loss: 1.0280 - accuracy: 0.6692 - val_loss: 0.9983 - val_accuracy: 0.6730
# Epoch 4/10
# 94/94 [==============================] - 7s 73ms/step - loss: 1.0255 - accuracy: 0.6686 - val_loss: 0.9967 - val_accuracy: 0.6745
# Epoch 5/10
# 94/94 [==============================] - 7s 70ms/step - loss: 1.0276 - accuracy: 0.6694 - val_loss: 0.9891 - val_accuracy: 0.6755
# Epoch 6/10
# 94/94 [==============================] - 7s 71ms/step - loss: 1.0049 - accuracy: 0.6694 - val_loss: 0.9846 - val_accuracy: 0.6735
# Epoch 7/10
# 94/94 [==============================] - 7s 70ms/step - loss: 1.0107 - accuracy: 0.6697 - val_loss: 1.0475 - val_accuracy: 0.6750
# Epoch 8/10
# 94/94 [==============================] - 7s 71ms/step - loss: 1.0512 - accuracy: 0.6692 - val_loss: 1.0143 - val_accuracy: 0.6735
# Epoch 9/10
# 94/94 [==============================] - 7s 70ms/step - loss: 1.0103 - accuracy: 0.6699 - val_loss: 0.9859 - val_accuracy: 0.6730
# Epoch 10/10
# 94/94 [==============================] - 7s 71ms/step - loss: 1.0062 - accuracy: 0.6702 - val_loss: 0.9776 - val_accuracy: 0.6745
# Duration: 0:01:06.899579
# -----kernel size: 5-----
# Epoch 1/10
# 94/94 [==============================] - 6s 62ms/step - loss: 7.9169 - accuracy: 0.6391 - val_loss: 1.0564 - val_accuracy: 0.6735
# Epoch 2/10
# 94/94 [==============================] - 6s 62ms/step - loss: 1.0333 - accuracy: 0.6709 - val_loss: 0.9961 - val_accuracy: 0.6700
# Epoch 3/10
# 94/94 [==============================] - 6s 62ms/step - loss: 1.0281 - accuracy: 0.6684 - val_loss: 0.9722 - val_accuracy: 0.6750
# Epoch 4/10
# 94/94 [==============================] - 6s 61ms/step - loss: 1.0076 - accuracy: 0.6697 - val_loss: 1.0224 - val_accuracy: 0.6750
# Epoch 5/10
# 94/94 [==============================] - 6s 61ms/step - loss: 0.9798 - accuracy: 0.6674 - val_loss: 0.9765 - val_accuracy: 0.6755
# Epoch 6/10
# 94/94 [==============================] - 6s 62ms/step - loss: 0.9901 - accuracy: 0.6699 - val_loss: 1.0541 - val_accuracy: 0.6720
# Epoch 7/10
# 94/94 [==============================] - 6s 61ms/step - loss: 0.9406 - accuracy: 0.6731 - val_loss: 0.9025 - val_accuracy: 0.6786
# Epoch 8/10
# 94/94 [==============================] - 6s 64ms/step - loss: 0.8991 - accuracy: 0.6796 - val_loss: 0.8733 - val_accuracy: 0.6931
# Epoch 9/10
# 94/94 [==============================] - 6s 62ms/step - loss: 0.8708 - accuracy: 0.6841 - val_loss: 0.9101 - val_accuracy: 0.6906
# Epoch 10/10
# 94/94 [==============================] - 6s 61ms/step - loss: 0.8696 - accuracy: 0.6918 - val_loss: 0.9041 - val_accuracy: 0.6996
# Duration: 0:00:58.522154

# %% [markdown]
# ### 6.2: fit models with and without an additional dense layer with different pool sizes

# %%
#list of pool sizes to fit
pool_list = [1, 2, 3, 4, 5]

pool_dict = {}

for i in pool_list:

    #fit model with an additional dense layer
    start_time = datetime.now()
    print("-----pool size: " + str(i) + "-----")
    model = build_model(kernel_size = 2, pool_size = i, learning_rate = 0.001, optimizer_name = "Adam", additional_dense = True)
    history_true = model.fit(x_train,
                        y_train,
                        validation_data=(x_valid, y_valid),
                        batch_size = 64,
                        epochs = 10)

    end_time = datetime.now()
    print('Duration: {}'.format(end_time - start_time))
    
    #fit model without an additional dense layer
    start_time = datetime.now()
    print("-----pool size: " + str(i) + "-----")
    model = build_model(kernel_size = 2, pool_size = i, learning_rate = 0.001, optimizer_name = "Adam", additional_dense = False)
    history_false = model.fit(x_train,
                        y_train,
                        validation_data=(x_valid, y_valid),
                        batch_size = 64,
                        epochs = 10)

    end_time = datetime.now()
    print('Duration: {}'.format(end_time - start_time))
    
    #store results
    pool_dict[i] = [history_true.history['accuracy'][-1], history_true.history['val_accuracy'][-1], history_false.history['accuracy'][-1], history_false.history['val_accuracy'][-1]]
# Out:
# -----pool size: 1-----
# Epoch 1/10
# 94/94 [==============================] - 43s 448ms/step - loss: 97.8536 - accuracy: 0.6038 - val_loss: 0.9714 - val_accuracy: 0.6640
# Epoch 2/10
# 94/94 [==============================] - 42s 452ms/step - loss: 1.0031 - accuracy: 0.6709 - val_loss: 0.9627 - val_accuracy: 0.6735
# Epoch 3/10
# 94/94 [==============================] - 42s 445ms/step - loss: 0.9435 - accuracy: 0.6758 - val_loss: 0.9353 - val_accuracy: 0.6710
# Epoch 4/10
# 94/94 [==============================] - 42s 447ms/step - loss: 0.8788 - accuracy: 0.6890 - val_loss: 0.8902 - val_accuracy: 0.6775
# Epoch 5/10
# 94/94 [==============================] - 42s 445ms/step - loss: 0.8476 - accuracy: 0.6977 - val_loss: 0.8551 - val_accuracy: 0.6956
# Epoch 6/10
# 94/94 [==============================] - 42s 446ms/step - loss: 0.8094 - accuracy: 0.7166 - val_loss: 0.8618 - val_accuracy: 0.7022
# Epoch 7/10
# 94/94 [==============================] - 42s 444ms/step - loss: 0.7589 - accuracy: 0.7189 - val_loss: 0.8731 - val_accuracy: 0.7027
# Epoch 8/10
# 94/94 [==============================] - 42s 447ms/step - loss: 0.7337 - accuracy: 0.7350 - val_loss: 0.8797 - val_accuracy: 0.6951
# Epoch 9/10
# 94/94 [==============================] - 42s 445ms/step - loss: 0.6986 - accuracy: 0.7484 - val_loss: 0.8863 - val_accuracy: 0.6811
# Epoch 10/10
# 94/94 [==============================] - 42s 449ms/step - loss: 0.6539 - accuracy: 0.7626 - val_loss: 0.8792 - val_accuracy: 0.6966
# Duration: 0:07:00.555935
# -----pool size: 1-----
# Epoch 1/10
# 94/94 [==============================] - 42s 438ms/step - loss: 210.5607 - accuracy: 0.6031 - val_loss: 0.9681 - val_accuracy: 0.6745
# Epoch 2/10
# 94/94 [==============================] - 41s 435ms/step - loss: 0.9885 - accuracy: 0.6689 - val_loss: 0.9466 - val_accuracy: 0.6770
# Epoch 3/10
# 94/94 [==============================] - 41s 440ms/step - loss: 0.9248 - accuracy: 0.6825 - val_loss: 0.9044 - val_accuracy: 0.6861
# Epoch 4/10
# 94/94 [==============================] - 41s 439ms/step - loss: 0.8633 - accuracy: 0.6957 - val_loss: 0.9052 - val_accuracy: 0.6821
# Epoch 5/10
# 94/94 [==============================] - 41s 435ms/step - loss: 0.8248 - accuracy: 0.7121 - val_loss: 0.9023 - val_accuracy: 0.6781
# Epoch 6/10
# 94/94 [==============================] - 41s 439ms/step - loss: 0.7966 - accuracy: 0.7164 - val_loss: 0.9212 - val_accuracy: 0.6906
# Epoch 7/10
# 94/94 [==============================] - 42s 443ms/step - loss: 0.7328 - accuracy: 0.7365 - val_loss: 0.9401 - val_accuracy: 0.6951
# Epoch 8/10
# 94/94 [==============================] - 41s 436ms/step - loss: 0.7048 - accuracy: 0.7466 - val_loss: 0.9416 - val_accuracy: 0.6836
# Epoch 9/10
# 94/94 [==============================] - 41s 435ms/step - loss: 0.6805 - accuracy: 0.7554 - val_loss: 1.0067 - val_accuracy: 0.6971
# Epoch 10/10
# 94/94 [==============================] - 41s 441ms/step - loss: 0.6042 - accuracy: 0.7849 - val_loss: 1.1468 - val_accuracy: 0.6826
# Duration: 0:06:52.279091
# -----pool size: 2-----
# Epoch 1/10
# 94/94 [==============================] - 4s 41ms/step - loss: 14.9159 - accuracy: 0.6212 - val_loss: 0.9020 - val_accuracy: 0.6861
# Epoch 2/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.9308 - accuracy: 0.6746 - val_loss: 0.8762 - val_accuracy: 0.6796
# Epoch 3/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8672 - accuracy: 0.6865 - val_loss: 0.8362 - val_accuracy: 0.6921
# Epoch 4/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8324 - accuracy: 0.6937 - val_loss: 0.7732 - val_accuracy: 0.7137
# Epoch 5/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8195 - accuracy: 0.7041 - val_loss: 0.8022 - val_accuracy: 0.7112
# Epoch 6/10
# 94/94 [==============================] - 4s 41ms/step - loss: 0.7933 - accuracy: 0.7121 - val_loss: 0.8009 - val_accuracy: 0.7042
# Epoch 7/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.7697 - accuracy: 0.7129 - val_loss: 0.7779 - val_accuracy: 0.7097
# Epoch 8/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.7590 - accuracy: 0.7195 - val_loss: 0.8048 - val_accuracy: 0.6996
# Epoch 9/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.7456 - accuracy: 0.7250 - val_loss: 0.8217 - val_accuracy: 0.6981
# Epoch 10/10
# 94/94 [==============================] - 4s 41ms/step - loss: 0.7042 - accuracy: 0.7419 - val_loss: 0.8173 - val_accuracy: 0.6911
# Duration: 0:00:38.231527
# -----pool size: 2-----
# Epoch 1/10
# 94/94 [==============================] - 3s 33ms/step - loss: 19.6117 - accuracy: 0.5993 - val_loss: 0.9198 - val_accuracy: 0.6821
# Epoch 2/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.9454 - accuracy: 0.6701 - val_loss: 0.9163 - val_accuracy: 0.6775
# Epoch 3/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.9032 - accuracy: 0.6776 - val_loss: 0.8906 - val_accuracy: 0.6770
# Epoch 4/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.8540 - accuracy: 0.6913 - val_loss: 0.8681 - val_accuracy: 0.6876
# Epoch 5/10
# 94/94 [==============================] - 3s 35ms/step - loss: 0.8376 - accuracy: 0.7025 - val_loss: 0.8232 - val_accuracy: 0.7007
# Epoch 6/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.8110 - accuracy: 0.7112 - val_loss: 0.8568 - val_accuracy: 0.6921
# Epoch 7/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7700 - accuracy: 0.7200 - val_loss: 0.8214 - val_accuracy: 0.7062
# Epoch 8/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7515 - accuracy: 0.7288 - val_loss: 0.8686 - val_accuracy: 0.6891
# Epoch 9/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7174 - accuracy: 0.7379 - val_loss: 0.8197 - val_accuracy: 0.7082
# Epoch 10/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.6904 - accuracy: 0.7441 - val_loss: 0.8271 - val_accuracy: 0.7092
# Duration: 0:00:29.910609
# -----pool size: 3-----
# Epoch 1/10
# 94/94 [==============================] - 3s 22ms/step - loss: 6.7343 - accuracy: 0.6168 - val_loss: 0.9132 - val_accuracy: 0.6871
# Epoch 2/10
# 94/94 [==============================] - 2s 21ms/step - loss: 0.9162 - accuracy: 0.6779 - val_loss: 0.8697 - val_accuracy: 0.6896
# Epoch 3/10
# 94/94 [==============================] - 2s 21ms/step - loss: 0.8783 - accuracy: 0.6873 - val_loss: 0.8304 - val_accuracy: 0.7042
# Epoch 4/10
# 94/94 [==============================] - 2s 21ms/step - loss: 0.8547 - accuracy: 0.6937 - val_loss: 0.8026 - val_accuracy: 0.7142
# Epoch 5/10
# 94/94 [==============================] - 2s 21ms/step - loss: 0.8240 - accuracy: 0.6979 - val_loss: 0.7699 - val_accuracy: 0.7157
# Epoch 6/10
# 94/94 [==============================] - 2s 22ms/step - loss: 0.7968 - accuracy: 0.7059 - val_loss: 0.8244 - val_accuracy: 0.7092
# Epoch 7/10
# 94/94 [==============================] - 2s 21ms/step - loss: 0.7842 - accuracy: 0.7106 - val_loss: 0.7374 - val_accuracy: 0.7333
# Epoch 8/10
# 94/94 [==============================] - 2s 22ms/step - loss: 0.7538 - accuracy: 0.7216 - val_loss: 0.7826 - val_accuracy: 0.7167
# Epoch 9/10
# 94/94 [==============================] - 2s 21ms/step - loss: 0.7474 - accuracy: 0.7266 - val_loss: 0.7308 - val_accuracy: 0.7248
# Epoch 10/10
# 94/94 [==============================] - 2s 21ms/step - loss: 0.7374 - accuracy: 0.7243 - val_loss: 0.7935 - val_accuracy: 0.7167
# Duration: 0:00:20.832779
# -----pool size: 3-----
# Epoch 1/10
# 94/94 [==============================] - 2s 13ms/step - loss: 6.4443 - accuracy: 0.5957 - val_loss: 0.8974 - val_accuracy: 0.6836
# Epoch 2/10
# 94/94 [==============================] - 1s 12ms/step - loss: 0.9426 - accuracy: 0.6681 - val_loss: 0.8543 - val_accuracy: 0.6931
# Epoch 3/10
# 94/94 [==============================] - 1s 12ms/step - loss: 0.9113 - accuracy: 0.6763 - val_loss: 0.8917 - val_accuracy: 0.6981
# Epoch 4/10
# 94/94 [==============================] - 1s 12ms/step - loss: 0.8688 - accuracy: 0.6863 - val_loss: 0.8679 - val_accuracy: 0.7002
# Epoch 5/10
# 94/94 [==============================] - 1s 12ms/step - loss: 0.8377 - accuracy: 0.6957 - val_loss: 0.8544 - val_accuracy: 0.7012
# Epoch 6/10
# 94/94 [==============================] - 1s 12ms/step - loss: 0.8094 - accuracy: 0.7111 - val_loss: 0.8110 - val_accuracy: 0.7087
# Epoch 7/10
# 94/94 [==============================] - 1s 12ms/step - loss: 0.8120 - accuracy: 0.7014 - val_loss: 0.7834 - val_accuracy: 0.7177
# Epoch 8/10
# 94/94 [==============================] - 1s 12ms/step - loss: 0.7737 - accuracy: 0.7161 - val_loss: 0.7653 - val_accuracy: 0.7238
# Epoch 9/10
# 94/94 [==============================] - 1s 12ms/step - loss: 0.7581 - accuracy: 0.7218 - val_loss: 0.7941 - val_accuracy: 0.7228
# Epoch 10/10
# 94/94 [==============================] - 1s 13ms/step - loss: 0.7377 - accuracy: 0.7270 - val_loss: 0.7839 - val_accuracy: 0.7157
# Duration: 0:00:11.860480
# -----pool size: 4-----
# Epoch 1/10
# 94/94 [==============================] - 2s 16ms/step - loss: 3.3825 - accuracy: 0.6204 - val_loss: 0.8996 - val_accuracy: 0.6755
# Epoch 2/10
# 94/94 [==============================] - 1s 16ms/step - loss: 0.9213 - accuracy: 0.6709 - val_loss: 0.8647 - val_accuracy: 0.6906
# Epoch 3/10
# 94/94 [==============================] - 1s 16ms/step - loss: 0.8763 - accuracy: 0.6828 - val_loss: 0.8176 - val_accuracy: 0.7022
# Epoch 4/10
# 94/94 [==============================] - 1s 16ms/step - loss: 0.8602 - accuracy: 0.6821 - val_loss: 0.8282 - val_accuracy: 0.6956
# Epoch 5/10
# 94/94 [==============================] - 1s 16ms/step - loss: 0.8375 - accuracy: 0.6910 - val_loss: 0.8081 - val_accuracy: 0.7137
# Epoch 6/10
# 94/94 [==============================] - 1s 16ms/step - loss: 0.
10
# 94/94 [==============================] - 1s 15ms/step - loss: 0.7910 - accuracy: 0.7071 - val_loss: 0.7863 - val_accuracy: 0.7248
# Epoch 10/10
# 94/94 [==============================] - 1s 15ms/step - loss: 0.7851 - accuracy: 0.7101 - val_loss: 0.7798 - val_accuracy: 0.7117
# Duration: 0:00:14.812142
# -----pool size: 5-----
# Epoch 1/10
# 94/94 [==============================] - 1s 6ms/step - loss: 4.2642 - accuracy: 0.5665 - val_loss: 0.9324 - val_accuracy: 0.6846
# Epoch 2/10
# 94/94 [==============================] - 1s 6ms/step - loss: 0.9661 - accuracy: 0.6679 - val_loss: 0.8757 - val_accuracy: 0.7052
# Epoch 3/10
# 94/94 [==============================] - 1s 6ms/step - loss: 0.9152 - accuracy: 0.6739 - val_loss: 0.8502 - val_accuracy: 0.6991
# Epoch 4/10
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8869 - accuracy: 0.6843 - val_loss: 0.8131 - val_accuracy: 0.7107
# Epoch 5/10
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8587 - accuracy: 0.6913 - val_loss: 0.7885 - val_accuracy: 0.7313
# Epoch 6/10
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8366 - accuracy: 0.7025 - val_loss: 0.8125 - val_accuracy: 0.7107
# Epoch 7/10
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8239 - accuracy: 0.7007 - val_loss: 0.7757 - val_accuracy: 0.7263
# Epoch 8/10
# 94/94 [==============================] - 1s 6ms/step - loss: 0.8088 - accuracy: 0.7012 - val_loss: 0.8208 - val_accuracy: 0.7062
# Epoch 9/10
# 94/94 [==============================] - 1s 6ms/step - loss: 0.7980 - accuracy: 0.7089 - val_loss: 0.7482 - val_accuracy: 0.7358
# Epoch 10/10
# 94/94 [==============================] - 1s 6ms/step - loss: 0.7892 - accuracy: 0.7081 - val_loss: 0.7368 - val_accuracy: 0.7258
# Duration: 0:00:05.760210

# %% [markdown]
# ### 6.3: fit models with and without an additional dense layer with different learning rates

# %%
#list of learning rates to fit
learning_list = [0.001, 0.01, 0.1, 1]

learning_dict = {}

for i in learning_list:

    #fit model with an additional dense layer
    start_time = datetime.now()
    print("-----learning_rate: " + str(i) + "-----")
    model = build_model(kernel_size = 2, pool_size = 2, learning_rate = i, optimizer_name = "Adam", additional_dense = True)
    history_true = model.fit(x_train,
                        y_train,
                        validation_data=(x_valid, y_valid),
                        batch_size = 64,
                        epochs = 10)

    end_time = datetime.now()
    print('Duration: {}'.format(end_time - start_time))
    
    #fit model without an additional dense layer
    start_time = datetime.now()
    print("-----learning_rate: " + str(i) + "-----")
    model = build_model(kernel_size = 2, pool_size = 2, learning_rate = i, optimizer_name = "Adam", additional_dense = False)
    history_false = model.fit(x_train,
                        y_train,
                        validation_data=(x_valid, y_valid),
                        batch_size = 64,
                        epochs = 10)

    end_time = datetime.now()
    print('Duration: {}'.format(end_time - start_time))
    
    #store results
    learning_dict[i] = [history_true.history['accuracy'][-1], history_true.history['val_accuracy'][-1], history_false.history['accuracy'][-1], history_false.history['val_accuracy'][-1]]
# Out:
# -----learning_rate: 0.001-----
# Epoch 1/10
# 94/94 [==============================] - 4s 41ms/step - loss: 9.9540 - accuracy: 0.6138 - val_loss: 0.9272 - val_accuracy: 0.6755
# Epoch 2/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.9500 - accuracy: 0.6691 - val_loss: 0.9033 - val_accuracy: 0.6791
# Epoch 3/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.9241 - accuracy: 0.6701 - val_loss: 0.8499 - val_accuracy: 0.6956
# Epoch 4/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8891 - accuracy: 0.6754 - val_loss: 0.8491 - val_accuracy: 0.6971
# Epoch 5/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8755 - accuracy: 0.6843 - val_loss: 0.9018 - val_accuracy: 0.6821
# Epoch 6/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8603 - accuracy: 0.6878 - val_loss: 0.8441 - val_accuracy: 0.6996
# Epoch 7/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8372 - accuracy: 0.6989 - val_loss: 0.8841 - val_accuracy: 0.6675
# Epoch 8/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8202 - accuracy: 0.7004 - val_loss: 0.8060 - val_accuracy: 0.7097
# Epoch 9/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8011 - accuracy: 0.7094 - val_loss: 0.8722 - val_accuracy: 0.6685
# Epoch 10/10
# 94/94 [==============================] - 4s 44ms/step - loss: 0.7847 - accuracy: 0.7128 - val_loss: 0.7908 - val_accuracy: 0.7197
# Duration: 0:00:38.450487
# -----learning_rate: 0.001-----
# Epoch 1/10
# 94/94 [==============================] - 3s 31ms/step - loss: 15.8991 - accuracy: 0.6033 - val_loss: 0.8884 - val_accuracy: 0.6871
# Epoch 2/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.9285 - accuracy: 0.6729 - val_loss: 0.8586 - val_accuracy: 0.6871
# Epoch 3/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.8828 - accuracy: 0.6905 - val_loss: 0.8459 - val_accuracy: 0.7092
# Epoch 4/10
# 94/94 [==============================] - 3s 33ms/step - loss: 0.8505 - accuracy: 0.6955 - val_loss: 0.8296 - val_accuracy: 0.7057
# Epoch 5/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.8109 - accuracy: 0.7121 - val_loss: 0.8131 - val_accuracy: 0.7002
# Epoch 6/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7775 - accuracy: 0.7169 - val_loss: 0.7897 - val_accuracy: 0.7207
# Epoch 7/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.7677 - accuracy: 0.7186 - val_loss: 0.7929 - val_accuracy: 0.7112
# Epoch 8/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.7321 - accuracy: 0.7340 - val_loss: 0.7752 - val_accuracy: 0.7263
# Epoch 9/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.7014 - accuracy: 0.7350 - val_loss: 0.7581 - val_accuracy: 0.7162
# Epoch 10/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.6751 - accuracy: 0.7508 - val_loss: 0.7737 - val_accuracy: 0.7223
# Duration: 0:00:29.379779
# -----learning_rate: 0.01-----
# Epoch 1/10
# 94/94 [==============================] - 4s 41ms/step - loss: 98.2768 - accuracy: 0.6153 - val_loss: 1.1443 - val_accuracy: 0.6735
# Epoch 2/10
# 94/94 [==============================] - 4s 39ms/step - loss: 1.1155 - accuracy: 0.6679 - val_loss: 1.0657 - val_accuracy: 0.6735
# Epoch 3/10
# 94/94 [==============================] - 4s 39ms/step - loss: 1.0869 - accuracy: 0.6684 - val_loss: 1.0285 - val_accuracy: 0.6735
# Epoch 4/10
# 94/94 [==============================] - 4s 39ms/step - loss: 1.0765 - accuracy: 0.6682 - val_loss: 1.0201 - val_accuracy: 0.6735
# Epoch 5/10
# 94/94 [==============================] - 4s 40ms/step - loss: 1.0647 - accuracy: 0.6689 - val_loss: 1.0663 - val_accuracy: 0.6735
# Epoch 6/10
# 94/94 [==============================] - 4s 39ms/step - loss: 1.0582 - accuracy: 0.6684 - val_loss: 1.0222 - val_accuracy: 0.6735
# Epoch 7/10
# 94/94 [==============================] - 4s 39ms/step - loss: 1.0527 - accuracy: 0.6694 - val_loss: 1.0635 - val_accuracy: 0.6735
# Epoch 8/10
# 94/94 [==============================] - 4s 39ms/step - loss: 1.0476 - accuracy: 0.6684 - val_loss: 1.0191 - val_accuracy: 0.6735
# Epoch 9/10
# 94/94 [==============================] - 4s 40ms/step - loss: 1.0402 - accuracy: 0.6689 - val_loss: 1.0206 - val_accuracy: 0.6735
# Epoch 10/10
# 94/94 [==============================] - 4s 40ms/step - loss: 1.0317 - accuracy: 0.6686 - val_loss: 1.0637 - val_accuracy: 0.6735
# Duration: 0:00:37.689302
# -----learning_rate: 0.01-----
# Epoch 1/10
# 94/94 [==============================] - 3s 31ms/step - loss: 43.3921 - accuracy: 0.6316 - val_loss: 1.0301 - val_accuracy: 0.6735
# Epoch 2/10
# 94/94 [==============================] - 3s 31ms/step - loss: 1.0502 - accuracy: 0.6671 - val_loss: 1.0085 - val_accuracy: 0.6725
# Epoch 3/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.0472 - accuracy: 0.6686 - val_loss: 1.0014 - val_accuracy: 0.6735
# Epoch 4/10
# 94/94 [==============================] - 3s 31ms/step - loss: 1.0410 - accuracy: 0.6694 - val_loss: 1.0057 - val_accuracy: 0.6735
# Epoch 5/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.1058 - accuracy: 0.6697 - val_loss: 1.1202 - val_accuracy: 0.6725
# Epoch 6/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.0842 - accuracy: 0.6687 - val_loss: 1.0351 - val_accuracy: 0.6720
# Epoch 7/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.0457 - accuracy: 0.6689 - val_loss: 1.0112 - val_accuracy: 0.6675
# Epoch 8/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.0497 - accuracy: 0.6699 - val_loss: 1.0736 - val_accuracy: 0.6735
# Epoch 9/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.1172 - accuracy: 0.6672 - val_loss: 1.0155 - val_accuracy: 0.6725
# Epoch 10/10
# 94/94 [==============================] - 3s 31ms/step - loss: 1.0518 - accuracy: 0.6686 - val_loss: 1.0598 - val_accuracy: 0.6735
# Duration: 0:00:29.106394
# -----learning_rate: 0.1-----
# Epoch 1/10
# 94/94 [==============================] - 4s 40ms/step - loss: 91877.7500 - accuracy: 0.6165 - val_loss: 1.1248 - val_accuracy: 0.6735
# Epoch 2/10
# 94/94 [==============================] -
- val_accuracy: 0.6735
# Epoch 8/10
# 94/94 [==============================] - 3s 34ms/step - loss: 1.1614 - accuracy: 0.6687 - val_loss: 1.1448 - val_accuracy: 0.6735
# Epoch 9/10
# 94/94 [==============================] - 3s 31ms/step - loss: 1.1678 - accuracy: 0.6687 - val_loss: 1.1569 - val_accuracy: 0.6735
# Epoch 10/10
# 94/94 [==============================] - 3s 31ms/step - loss: 1.1603 - accuracy: 0.6687 - val_loss: 1.1568 - val_accuracy: 0.6735
# Duration: 0:00:31.439857

# %% [markdown]
# ### 6.4: fit models with and without an additional dense layer with different batch sizes

# %%
#list of batch sizes to fit
batch_list = [32, 64, 128, 256]

batch_dict = {}

for i in batch_list:

    #fit model with an additional dense layer
    start_time = datetime.now()
    print("-----batch size: " + str(i) + "-----")
    model = build_model(kernel_size = 2, pool_size = 2, learning_rate = 0.001, optimizer_name = "Adam", additional_dense = True)
    history_true = model.fit(x_train,
                        y_train,
                        validation_data=(x_valid, y_valid),
                        batch_size = i,
                        epochs = 10)

    end_time = datetime.now()
    print('Duration: {}'.format(end_time - start_time))
    
    #fit model without an additional dense layer
    start_time = datetime.now()
    print("-----batch size: " + str(i) + "-----")
    model = build_model(kernel_size = 2, pool_size = 2, learning_rate = 0.001, optimizer_name = "Adam", additional_dense = False)
    history_false = model.fit(x_train,
                        y_train,
                        validation_data=(x_valid, y_valid),
                        batch_size = i,
                        epochs = 10)

    end_time = datetime.now()
    print('Duration: {}'.format(end_time - start_time))
    
    #store results
    batch_dict[i] = [history_true.history['accuracy'][-1], history_true.history['val_accuracy'][-1], history_false.history['accuracy'][-1], history_false.history['val_accuracy'][-1]]
# Out:
# -----batch size: 32-----
# Epoch 1/10
# 187/187 [==============================] - 7s 34ms/step - loss: 7.3976 - accuracy: 0.6348 - val_loss: 0.9447 - val_accuracy: 0.6730
# Epoch 2/10
# 187/187 [==============================] - 6s 33ms/step - loss: 0.9815 - accuracy: 0.6692 - val_loss: 0.9113 - val_accuracy: 0.6665
# Epoch 3/10
# 187/187 [==============================] - 6s 34ms/step - loss: 0.9348 - accuracy: 0.6722 - val_loss: 0.8702 - val_accuracy: 0.6971
# Epoch 4/10
# 187/187 [==============================] - 6s 34ms/step - loss: 0.8800 - accuracy: 0.6855 - val_loss: 0.8346 - val_accuracy: 0.6991
# Epoch 5/10
# 187/187 [==============================] - 6s 33ms/step - loss: 0.8489 - accuracy: 0.6940 - val_loss: 0.8884 - val_accuracy: 0.6720
# Epoch 6/10
# 187/187 [==============================] - 6s 34ms/step - loss: 0.8049 - accuracy: 0.7041 - val_loss: 0.8017 - val_accuracy: 0.7052
# Epoch 7/10
# 187/187 [==============================] - 6s 33ms/step - loss: 0.8343 - accuracy: 0.6999 - val_loss: 0.8252 - val_accuracy: 0.7032
# Epoch 8/10
# 187/187 [==============================] - 6s 33ms/step - loss: 0.7887 - accuracy: 0.7134 - val_loss: 0.8524 - val_accuracy: 0.6786
# Epoch 9/10
# 187/187 [==============================] - 6s 33ms/step - loss: 0.7506 - accuracy: 0.7253 - val_loss: 0.8047 - val_accuracy: 0.6981
# Epoch 10/10
# 187/187 [==============================] - 6s 33ms/step - loss: 0.7309 - accuracy: 0.7323 - val_loss: 0.8161 - val_accuracy: 0.7062
# Duration: 0:01:02.971078
# -----batch size: 32-----
# Epoch 1/10
# 187/187 [==============================] - 5s 26ms/step - loss: 10.8774 - accuracy: 0.6334 - val_loss: 0.9543 - val_accuracy: 0.6750
# Epoch 2/10
# 187/187 [==============================] - 5s 25ms/step - loss: 0.9729 - accuracy: 0.6687 - val_loss: 0.9380 - val_accuracy: 0.6675
# Epoch 3/10
# 187/187 [==============================] - 5s 25ms/step - loss: 0.9475 - accuracy: 0.6717 - val_loss: 0.9099 - val_accuracy: 0.6665
# Epoch 4/10
# 187/187 [==============================] - 5s 25ms/step - loss: 0.9055 - accuracy: 0.6791 - val_loss: 0.8643 - val_accuracy: 0.6836
# Epoch 5/10
# 187/187 [==============================] - 5s 25ms/step - loss: 0.8802 - accuracy: 0.6895 - val_loss: 0.8751 - val_accuracy: 0.6856
# Epoch 6/10
# 187/187 [==============================] - 5s 25ms/step - loss: 0.8789 - accuracy: 0.6868 - val_loss: 0.9031 - val_accuracy: 0.6916
# Epoch 7/10
# 187/187 [==============================] - 5s 25ms/step - loss: 0.8575 - accuracy: 0.6964 - val_loss: 0.8742 - val_accuracy: 0.6861
# Epoch 8/10
# 187/187 [==============================] - 5s 25ms/step - loss: 0.8541 - accuracy: 0.6969 - val_loss: 0.8990 - val_accuracy: 0.6796
# Epoch 9/10
# 187/187 [==============================] - 5s 25ms/step - loss: 0.8518 - accuracy: 0.6982 - val_loss: 0.9349 - val_accuracy: 0.6680
# Epoch 10/10
# 187/187 [==============================] - 5s 25ms/step - loss: 0.8195 - accuracy: 0.7086 - val_loss: 0.8710 - val_accuracy: 0.7022
# Duration: 0:00:47.621717
# -----batch size: 64-----
# Epoch 1/10
# 94/94 [==============================] - 4s 41ms/step - loss: 14.2754 - accuracy: 0.6078 - val_loss: 0.9090 - val_accuracy: 0.6745
# Epoch 2/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.9604 - accuracy: 0.6714 - val_loss: 0.8870 - val_accuracy: 0.6951
# Epoch 3/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.9232 - accuracy: 0.6768 - val_loss: 0.8780 - val_accuracy: 0.7122
# Epoch 4/10
# 94/94 [==============================] - 4s 39ms/step - loss: 0.8871 - accuracy: 0.6828 - val_loss: 0.8739 - val_accuracy: 0.7002
# Epoch 5/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8519 - accuracy: 0.6915 - val_loss: 0.8903 - val_accuracy: 0.6911
# Epoch 6/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8263 - accuracy: 0.7047 - val_loss: 0.8016 - val_accuracy: 0.7037
# Epoch 7/10
# 94/94 [==============================] - 4s 42ms/step - loss: 0.8022 - accuracy: 0.7104 - val_loss: 0.8105 - val_accuracy: 0.7182
# Epoch 8/10
# 94/94 [==============================] - 4s 41ms/step - loss: 0.7724 - accuracy: 0.7188 - val_loss: 0.8094 - val_accuracy: 0.7137
# Epoch 9/10
# 94/94 [==============================] - 4s 41ms/step - loss: 0.7649 - accuracy: 0.7297 - val_loss: 0.7969 - val_accuracy: 0.7233
# Epoch 10/10
# 94/94 [==============================] - 4s 44ms/step - loss: 0.7350 - accuracy: 0.7277 - val_loss: 0.7648 - val_accuracy: 0.7238
# Duration: 0:00:38.754124
# -----batch size: 64-----
# Epoch 1/10
# 94/94 [==============================] - 3s 32ms/step - loss: 16.9783 - accuracy: 0.5989 - val_loss: 0.9571 - val_accuracy: 0.6680
# Epoch 2/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.9648 - accuracy: 0.6662 - val_loss: 0.9122 - val_accuracy: 0.6775
# Epoch 3/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.9227 - accuracy: 0.6748 - val_loss: 0.9087 - val_accuracy: 0.6765
# Epoch 4/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.8673 - accuracy: 0.6843 - val_loss: 0.8691 - val_accuracy: 0.6796
# Epoch 5/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.8608 - accuracy: 0.6873 - val_loss: 0.8853 - val_accuracy: 0.6851
# Epoch 6/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.8612 - accuracy: 0.6883 - val_loss: 0.8322 - val_accuracy: 0.6951
# Epoch 7/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.8391 - accuracy: 0.6930 - val_loss: 0.8395 - val_accuracy: 0.6881
# Epoch 8/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.8030 - accuracy: 0.7039 - val_loss: 0.8494 - val_accuracy: 0.6886
# Epoch 9/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.8038 - accuracy: 0.7057 - val_loss: 0.8454 - val_accuracy: 0.6946
# Epoch 10/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7909 - accuracy: 0.7074 - val_loss: 0.8612 - val_accuracy: 0.6966
# Duration: 0:00:29.231412
# -----batch size: 128-----
# Epoch 1/10
# 47/47 [==============================] - 4s 67ms/step - loss: 24.7085 - accuracy: 0.5788 - val_loss: 0.9652 - val_accuracy: 0.6725
# Epoch 2/10
# 47/47 [==============================] - 3s 64ms/step - loss: 0.9734 - accuracy: 0.6644 - val_loss: 0.9051 - val_accuracy: 0.6856
# Epoch 3/10
# 47/47 [==============================] - 3s 64ms/step - loss: 0.9137 - accuracy: 0.6786 - val_loss: 0.8594 - val_accuracy: 0.6750
# Epoch 4/10
# 47/47 [==============================] - 3s 64ms/step - loss: 0.8790 - accuracy: 0.6878 - val_loss: 0.8360 - val_accuracy: 0.7042
# Epoch 5/10
# 47/47 [==============================] - 3s 64ms/step - loss: 0.8609 - accuracy: 0.6908 - val_loss: 0.8187 - val_accuracy: 0.7177
# Epoch 6/10
# 47/47 [==============================] - 3s 64ms/step - loss: 0.8561 - accuracy: 0.6881 - val_loss: 0.8315 - val_accuracy: 0.7002
# Epoch 7/10
# 47/47 [==============================] - 3s 65ms/step - loss: 0.8244 - accuracy: 0.6989 - val_loss: 0.7828 - val_accuracy: 0.7152
# Epoch 8/10
# 47/47 [==============================] - 3s 64ms/step - loss: 0.8084 - accuracy: 0.7044 - val_loss: 0.7697 - val_accuracy: 0.7107
# Epoch 9/10
# 47/47 [==============================] - 3s 64ms/step - loss: 0.7755 - accuracy: 0.7124 - val_loss: 0.7415 - val_accuracy: 0.7298
# Epoch 10/10
# 47/47 [==============================] - 3s 64ms/step - loss: 0.7676 - accuracy: 0.7163 - val_loss: 0.8246 - val_accuracy: 0.6996
# Duration: 0:00:30.672988
# -----batch size: 128-----
# Epoch 1/10
# 47/47 [==============================] - 3s 54ms/step - loss: 27.9225 - accuracy: 0.5624 - val_loss: 0.9344 - val_accuracy: 0.6770
# Epoch 2/10
# 47/47 [==============================] - 3s 55ms/step - loss: 0.9238 - accuracy: 0.6793 - val_loss: 0.8185 - val_accuracy: 0.7072
# Epoch 3/10
# 47/47 [==============================] - 2s 52ms/step - loss: 0.8181 - accuracy: 0.7046 - val_loss: 0.7751 - val_accuracy: 0.7233
# Epoch 4/10
# 47/47 [==============================] - 2s 52ms/step - loss: 0.7559 - accuracy: 0.7233 - val_loss: 0.7502 - val_accuracy: 0.7137
# Epoch 5/10
# 47/47 [==============================] - 2s 52ms/step - loss: 0.7019 - accuracy: 0.7442 - val_loss: 0.7295 - val_accuracy: 0.7293
# Epoch 6/10
# 47/47 [==============================] - 2s 52ms/step - loss: 0.6567 - accuracy: 0.7613 - val_loss: 0.7735 - val_accuracy: 0.7268
# Epoch 7/10
# 47/47 [==============================] - 2s 53ms/step - loss: 0.6197 - accuracy: 0.7767 - val_loss: 0.7221 - val_accuracy: 0.7318
# Epoch 8/10
# 47/47 [==============================] - 3s 54ms/step - loss: 0.5906 - accuracy: 0.7844 - val_loss: 0.7260 - val_accuracy: 0.7308
# Epoch 9/10
# 47/47 [==============================] - 3s 54ms/step - loss: 0.5285 - accuracy: 0.8021 - val_loss: 0.7844 - val_accuracy: 0.7363
# Epoch 10/10
# 47/47 [==============================] - 2s 52ms/step - loss: 0.5031 - accuracy: 0.8197 - val_loss: 0.7581 - val_accuracy: 0.7308
# Duration: 0:00:25.385083
# -----batch size: 256-----
# Epoch 1/10
# 24/24 [==============================] - 3s 102ms/step - loss: 50.9661 - accuracy: 0.4772 - val_loss: 1.3114 - val_accuracy: 0.6715
# Epoch 2/10
# 24/24 [==============================] - 3s 111ms/step - loss: 1.1227 - accuracy: 0.6527 - val_loss: 0.9187 - val_accuracy: 0.6846
# Epoch 3/10
# 24/24 [==============================] - 2s 99ms/step - loss: 0.9316 - accuracy: 0.6828 - val_loss: 0.8550 - val_accuracy: 0.6981
# Epoch 4/10
# 24/24 [==============================] - 2s 99ms/step - loss: 0.8940 - accuracy: 0.6863 - val_loss: 0.8364 - val_accuracy: 0.7032
# Epoch 5/10
# 24/24 [==============================] - 2s 103ms/step - loss: 0.8450 - accuracy: 0.6960 - val_loss: 0.8058 - val_accuracy: 0.7077
# Epoch 6/10
# 24/24 [==============================] - 2s 98ms/step - loss: 0.8215 - accuracy: 0.7072 - val_loss: 0.7888 - val_accuracy: 0.7117
# Epoch 7/10
# 24/24 [==============================] - 2s 99ms/step - loss: 0.7968 - accuracy: 0.7084 - val_loss: 0.8078 - val_accuracy: 0.7042
# Epoch 8/10
# 24/24 [==============================] - 2s 99ms/step - loss: 0.7620 - accuracy: 0.7211 - val_loss: 0.7570 - val_accuracy: 0.7182
# Epoch 9/10
# 24/24 [==============================] - 2s 99ms/step - loss: 0.7590 - accuracy: 0.7218 - val_loss: 0.7662 - val_accuracy: 0.7263
# Epoch 10/10
# 24/24 [==============================] - 2s 99ms/step - loss: 0.7241 - accuracy: 0.7330 - val_loss: 0.7252 - val_accuracy: 0.7343
# Duration: 0:00:24.580215
# -----batch size: 256-----
# Epoch 1/10
# 24/24 [==============================] - 2s 89ms/step - loss: 46.3078 - accuracy: 0.5020 - val_loss: 1.5932 - val_accuracy: 0.6464
# Epoch 2/10
# 24/24 [==============================] - 2s 85ms/step - loss: 1.3445 - accuracy: 0.6122 - val_loss: 0.8958 - val_accuracy: 0.6851
# Epoch 3/10
# 24/24 [==============================] - 2s 84ms/step - loss: 0.9246 - accuracy: 0.6768 - val_loss: 0.8513 - val_accuracy: 0.6946
# Epoch 4/10
# 24/24 [==============================] - 2s 83ms/step - loss: 0.8687 - accuracy: 0.6920 - val_loss: 0.8399 - val_accuracy: 0.7052
# Epoch 5/10
# 24/24 [==============================] - 2s 84ms/step - loss: 0.8419 - accuracy: 0.6992 - val_loss: 0.8139 - val_accuracy: 0.7072
# Epoch 6/10
# 24/24 [==============================] - 2s 84ms/step - loss: 0.8020 - accuracy: 0.7112 - val_loss: 0.8109 - val_accuracy: 0.7142
# Epoch 7/10
# 24/24 [==============================] - 2s 83ms/step - loss: 0.7809 - accuracy: 0.7223 - val_loss: 0.7926 - val_accuracy: 0.7228
# Epoch 8/10
# 24/24 [==============================] - 2s 84ms/step - loss: 0.7482 - accuracy: 0.7310 - val_loss: 0.7876 - val_accuracy: 0.7167
# Epoch 9/10
# 24/24 [==============================] - 2s 87ms/step - loss: 0.7163 - accuracy: 0.7467 - val_loss: 0.7558 - val_accuracy: 0.7303
# Epoch 10/10
# 24/24 [==============================] - 2s 84ms/step - loss: 0.6830 - accuracy: 0.7541 - val_loss: 0.7606 - val_accuracy: 0.7273
# Duration: 0:00:20.679622

# %% [markdown]
# ### 6.5: fit models with and without an additional dense layer with different optimizers

# %%
#list of optimziers to fit
optimizer_list = ["Adam", "SGD", "Adagrad"]

optimizer_dict = {}

for i in optimizer_list:

    #fit model with an additional layer
    start_time = datetime.now()
    print("-----optimizer: " + i + "-----")
    model = build_model(kernel_size = 2, pool_size = 2, learning_rate = 0.001, optimizer_name = i, additional_dense = True)
    history_true = model.fit(x_train,
                        y_train,
                        validation_data=(x_valid, y_valid),
                        batch_size = 64,
                        epochs = 10)

    end_time = datetime.now()
    print('Duration: {}'.format(end_time - start_time))
    
    #fit model without an additional layer
    start_time = datetime.now()
    print("-----optimizer: " + i + "-----")
    model = build_model(kernel_size = 2, pool_size = 2, learning_rate = 0.001, optimizer_name = i, additional_dense = False)
    history_false = model.fit(x_train,
                        y_train,
                        validation_data=(x_valid, y_valid),
                        batch_size = 64,
                        epochs = 10)

    end_time = datetime.now()
    print('Duration: {}'.format(end_time - start_time))
    
    optimizer_dict[i] = [history_true.history['accuracy'][-1], history_true.history['val_accuracy'][-1], history_false.history['accuracy'][-1], history_false.history['val_accuracy'][-1]]
# Out:
# -----optimizer: Adam-----
# Epoch 1/10
# 94/94 [==============================] - 4s 40ms/step - loss: 17.1058 - accuracy: 0.6016 - val_loss: 0.9459 - val_accuracy: 0.6665
# Epoch 2/10
# 94/94 [==============================] - 4s 42ms/step - loss: 0.9777 - accuracy: 0.6729 - val_loss: 0.9301 - val_accuracy: 0.6856
# Epoch 3/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.9244 - accuracy: 0.6803 - val_loss: 0.9259 - val_accuracy: 0.6931
# Epoch 4/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.9271 - accuracy: 0.6736 - val_loss: 0.9036 - val_accuracy: 0.6901
# Epoch 5/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8723 - accuracy: 0.6900 - val_loss: 0.8453 - val_accuracy: 0.7047
# Epoch 6/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8784 - accuracy: 0.6915 - val_loss: 0.9057 - val_accuracy: 0.6479
# Epoch 7/10
# 94/94 [==============================] - 4s 39ms/step - loss: 0.8518 - accuracy: 0.6974 - val_loss: 0.8110 - val_accuracy: 0.7027
# Epoch 8/10
# 94/94 [==============================] - 4s 40ms/step - loss: 0.8316 - accuracy: 0.7051 - val_loss: 0.8091 - val_accuracy: 0.7082
# Epoch 9/10
# 94/94 [==============================] - 4s 42ms/step - loss: 0.8107 - accuracy: 0.7091 - val_loss: 0.8092 - val_accuracy: 0.7092
# Epoch 10/10
# 94/94 [==============================] - 4s 41ms/step - loss: 0.7774 - accuracy: 0.7184 - val_loss: 0.7860 - val_accuracy: 0.7107
# Duration: 0:00:38.535343
# -----optimizer: Adam-----
# Epoch 1/10
# 94/94 [==============================] - 3s 32ms/step - loss: 18.6742 - accuracy: 0.6041 - val_loss: 0.9101 - val_accuracy: 0.6811
# Epoch 2/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.9402 - accuracy: 0.6793 - val_loss: 0.8931 - val_accuracy: 0.6956
# Epoch 3/10
# 94/94 [==============================] - 3s 32ms/step - loss: 0.8839 - accuracy: 0.6843 - val_loss: 0.8911 - val_accuracy: 0.6876
# Epoch 4/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.8250 - accuracy: 0.7025 - val_loss: 0.8428 - val_accuracy: 0.6916
# Epoch 5/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.7976 - accuracy: 0.7133 - val_loss: 0.8521 - val_accuracy: 0.6871
# Epoch 6/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7532 - accuracy: 0.7261 - val_loss: 0.8313 - val_accuracy: 0.7072
# Epoch 7/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.7410 - accuracy: 0.7333 - val_loss: 0.8075 - val_accuracy: 0.7137
# Epoch 8/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.6994 - accuracy: 0.7414 - val_loss: 0.8403 - val_accuracy: 0.7032
# Epoch 9/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.6940 - accuracy: 0.7451 - val_loss: 0.8435 - val_accuracy: 0.7012
# Epoch 10/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.6641 - accuracy: 0.7554 - val_loss: 0.8117 - val_accuracy: 0.6966
# Duration: 0:00:29.568739
# -----optimizer: SGD-----
# Epoch 1/10
# 94/94 [==============================] - 4s 38ms/step - loss: 3.6548 - accuracy: 0.6135 - val_loss: 1.0088 - val_accuracy: 0.6735
# Epoch 2/10
# 94/94 [==============================] - 4s 40ms/step - loss: 1.0501 - accuracy: 0.6572 - val_loss: 0.9642 - val_accuracy: 0.6740
# Epoch 3/10
# 94/94 [==============================] - 4s 38ms/step - loss: 1.0140 - accuracy: 0.6639 - val_loss: 0.9391 - val_accuracy: 0.6745
# Epoch 4/10
# 94/94 [==============================] - 4s 38ms/step - loss: 0.9919 - accuracy: 0.6650 - val_loss: 0.9223 - val_accuracy: 0.6816
# Epoch 5/10
# 94/94 [==============================] - 4s 38ms/step - loss: 0.9733 - accuracy: 0.6714 - val_loss: 0.9139 - val_accuracy: 0.6770
# Epoch 6/10
# 94/94 [==============================] - 4s 38ms/step - loss: 0.9605 - accuracy: 0.6731 - val_loss: 0.9024 - val_accuracy: 0.6811
# Epoch 7/10
# 94/94 [==============================] - 4s 38ms/step - loss: 0.9511 - accuracy: 0.6738 - val_loss: 0.8921 - val_accuracy: 0.6951
# Epoch 8/10
# 94/94 [==============================] - 4s 39ms/step - loss: 0.9498 - accuracy: 0.6756 - val_loss: 0.8878 - val_accuracy: 0.6876
# Epoch 9/10
# 94/94 [==============================] - 4s 38ms/step - loss: 0.9343 - accuracy: 0.6716 - val_loss: 0.8741 - val_accuracy: 0.6866
# Epoch 10/10
# 94/94 [==============================] - 4s 38ms/step - loss: 0.9279 - accuracy: 0.6744 - val_loss: 0.8863 - val_accuracy: 0.6886
# Duration: 0:00:36.247348
# -----optimizer: SGD-----
# Epoch 1/10
# 94/94 [==============================] - 3s 31ms/step - loss: 6.4055 - accuracy: 0.6486 - val_loss: 1.0720 - val_accuracy: 0.6735
# Epoch 2/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.1121 - accuracy: 0.6664 - val_loss: 1.0308 - val_accuracy: 0.6735
# Epoch 3/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.0715 - accuracy: 0.6674 - val_loss: 1.0155 - val_accuracy: 0.6735
# Epoch 4/10
# 94/94 [==============================] - 3s 29ms/step - loss: 1.0557 - accuracy: 0.6664 - val_loss: 1.0117 - val_accuracy: 0.6730
# Epoch 5/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.0483 - accuracy: 0.6699 - val_loss: 1.0126 - val_accuracy: 0.6735
# Epoch 6/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.0385 - accuracy: 0.6684 - val_loss: 0.9924 - val_accuracy: 0.6730
# Epoch 7/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.0297 - accuracy: 0.6696 - val_loss: 1.0057 - val_accuracy: 0.6730
# Epoch 8/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.0180 - accuracy: 0.6682 - val_loss: 0.9733 - val_accuracy: 0.6735
# Epoch 9/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.0115 - accuracy: 0.6714 - val_loss: 0.9632 - val_accuracy: 0.6720
# Epoch 10/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.9957 - accuracy: 0.6716 - val_loss: 0.9529 - val_accuracy: 0.6735
# Duration: 0:00:28.240265
# -----optimizer: Adagrad-----
# Epoch 1/10
# 94/94 [==============================] - 4s 40ms/step - loss: 14.5111 - accuracy: 0.5224 - val_loss: 1.1776 - val_accuracy: 0.6444
# Epoch 2/10
# 94/94 [==============================] - 4s 39ms/step - loss: 1.2361 - accuracy: 0.6202 - val_loss: 0.9976 - val_accuracy: 0.6720
# Epoch 3/10
# 94/94 [==============================] - 4s 40ms/step - loss: 1.0703 - accuracy: 0.6553 - val_loss: 0.9689 - val_accuracy: 0.6625
# Epoch 4/10
# 94/94 [==============================] - 4s 42ms/step - loss: 1.0446 - accuracy: 0.6612 - val_loss: 0.9386 - val_accuracy: 0.6735
# Epoch 5/10
# 94/94 [==============================] - 4s 39ms/step - loss: 1.0221 - accuracy: 0.6610 - val_loss: 0.9332 - val_accuracy: 0.6740
# Epoch 6/10
# 94/94 [==============================] - 4s 39ms/step - loss: 1.0042 - accuracy: 0.6666 - val_loss: 0.9294 - val_accuracy: 0.6755
# Epoch 7/10
# 94/94 [==============================] - 4s 39ms/step - loss: 0.9844 - accuracy: 0.6707 - val_loss: 0.9263 - val_accuracy: 0.6735
# Epoch 8/10
# 94/94 [==============================] - 4s 39ms/step - loss: 0.9833 - accuracy: 0.6681 - val_loss: 0.8999 - val_accuracy: 0.6811
# Epoch 9/10
# 94/94 [==============================] - 4s 39ms/step - loss: 0.9620 - accuracy: 0.6738 - val_loss: 0.8930 - val_accuracy: 0.6896
# Epoch 10/10
# 94/94 [==============================] - 4s 39ms/step - loss: 0.9538 - accuracy: 0.6691 - val_loss: 0.8951 - val_accuracy: 0.6951
# Duration: 0:00:37.432505
# -----optimizer: Adagrad-----
# Epoch 1/10
# 94/94 [==============================] - 3s 31ms/step - loss: 23.2223 - accuracy: 0.5442 - val_loss: 1.0773 - val_accuracy: 0.6765
# Epoch 2/10
# 94/94 [==============================] - 3s 31ms/step - loss: 1.1047 - accuracy: 0.6493 - val_loss: 0.9650 - val_accuracy: 0.6781
# Epoch 3/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.0390 - accuracy: 0.6562 - val_loss: 0.9460 - val_accuracy: 0.6765
# Epoch 4/10
# 94/94 [==============================] - 3s 30ms/step - loss: 1.0122 - accuracy: 0.6612 - val_loss: 0.9323 - val_accuracy: 0.6816
# Epoch 5/10
# 94/94 [==============================] - 3s 31ms/step - loss: 1.0006 - accuracy: 0.6604 - val_loss: 0.9054 - val_accuracy: 0.6781
# Epoch 6/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.9899 - accuracy: 0.6746 - val_loss: 0.9391 - val_accuracy: 0.6811
# Epoch 7/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.9747 - accuracy: 0.6701 - val_loss: 0.9167 - val_accuracy: 0.6786
# Epoch 8/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.9672 - accuracy: 0.6706 - val_loss: 0.9300 - val_accuracy: 0.6871
# Epoch 9/10
# 94/94 [==============================] - 3s 30ms/step - loss: 0.9620 - accuracy: 0.6699 - val_loss: 0.8898 - val_accuracy: 0.6806
# Epoch 10/10
# 94/94 [==============================] - 3s 31ms/step - loss: 0.9484 - accuracy: 0.6746 - val_loss: 0.8947 - val_accuracy: 0.6811
# Duration: 0:00:29.064299

# %% [markdown]
# # 7: output results

# %%
import csv

kernel_table = []

for key in kernel_dict:
    kernel_table.append([key, kernel_dict[key][0], kernel_dict[key][1], kernel_dict[key][2], kernel_dict[key][3]])

with open('clean_kernel.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(kernel_table)

# %%
pool_table = []

for key in pool_dict:
    pool_table.append([key, pool_dict[key][0], pool_dict[key][1], pool_dict[key][2], pool_dict[key][3]])

with open('clean_pool.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(pool_table)

# %%
learning_table = []

for key in learning_dict:
    learning_table.append([key, learning_dict[key][0], learning_dict[key][1], learning_dict[key][2], learning_dict[key][3]])

with open('clean_learning.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(learning_table)

# %%
batch_table = []

for key in batch_dict:
    batch_table.append([key, batch_dict[key][0], batch_dict[key][1], batch_dict[key][2], batch_dict[key][3]])

with open('clean_batch.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(batch_table)

# %%
optimizer_table = []

for key in optimizer_dict:
    optimizer_table.append([key, optimizer_dict[key][0], optimizer_dict[key][1], optimizer_dict[key][2], optimizer_dict[key][3]])

with open('clean_optimizer.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerows(optimizer_table)
